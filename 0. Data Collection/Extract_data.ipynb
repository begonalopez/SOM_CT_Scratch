# %%
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in /opt/anaconda3/lib/python3.11/site-packages (2.0.25)
# Requirement already satisfied: typing-extensions>=4.6.0 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy) (3.0.1)
# Requirement already satisfied: pymysql in /opt/anaconda3/lib/python3.11/site-packages (1.1.1)

# %%
import pandas as pd
from sqlalchemy import create_engine
# Out:
# Requirement already satisfied: pymysql in /opt/anaconda3/lib/python3.11/site-packages (1.1.1)

# %%
# Database credentials
user = 'root'
password = 'scratch!'
host = '127.0.0.1'
port = '3306'  # Default MySQL port
database = 'SCRATCH'

# Create the connection string
connection_string = f'mysql+pymysql://{user}:{password}@{host}:{port}/{database}'

# Create the database engine
engine = create_engine(connection_string)

# %%
# Write your query
query = """
SELECT *
FROM SCRATCH.project as P
INNER JOIN SCRATCH.grades as G
ON (P.p_ID = G.project_ID);
"""
# Execute the query and load data into a DataFrame
df = pd.read_sql(query, engine)

# %%
df
# Out:
#             p_ID                                      project-name  \
# 0       60002538                           Oink Girl and Piggy Boy
# 1       60034304                                       crossy road
# 2       60058876                                            trippy
# 3       60063608                                         scrolling
# 4       60068444                                   Ask me anything
# ...          ...                                               ...
# 231045  99965457                                           Escape
# 231046  99965561        Social Media Explore Starter Project remix
# 231047  99965607                                τÜäπüéπüªπé▓πâ╝πâá
# 231048  99965707                      Zombies: Black Ops 3 remix-2
# 231049  99965776  δÅäφï░δïÿX∞╡╕∞╡╕∞Ü░δïÿ φòÿδéÿδæÿ φî¼φü┤δƒ╜ remix
#
#                 username  total-views  total-remixes  total-favorites  \
# 0       thepigmaster1234          1.0            0.0              0.0
# 1             ses_collab         33.0            0.0              3.0
# 2                cometku          3.0            0.0              1.0
# 3                Wi11iam          1.0            0.0              0.0
# 4            Featherleap          1.0            0.0              0.0
# ...                  ...          ...            ...              ...
# 231045       ChenulGomes          1.0            0.0              0.0
# 231046          cs263993          1.0            0.0              0.0
# 231047      solur_member          1.0            0.0              0.0
# 231048           cry7tal          1.0            0.0              0.0
# 231049             jkseo          1.0            0.0              0.0
#
#         total-loves  is-remix  project_ID  Abstraction  Parallelism  Logic  \
# 0               0.0         0    60002538          0.0          0.0    0.0
# 1               2.0         0    60034304          3.0          1.0    3.0
# 2               1.0         0    60058876          2.0          0.0    2.0
# 3               0.0         0    60063608          1.0          1.0    0.0
# 4               0.0         0    60068444          0.0          0.0    1.0
# ...             ...       ...         ...          ...          ...    ...
# 231045          0.0         0    99965457          1.0          1.0    3.0
# 231046          0.0         0    99965561          0.0          0.0    0.0
# 231047          0.0         0    99965607          3.0          3.0    1.0
# 231048          0.0         0    99965707          3.0          3.0    3.0
# 231049          0.0         0    99965776          1.0          1.0    0.0
#
#         Synchronization  FlowControl  UserInteractivity  DataRepresentation  \
# 0                   0.0          1.0                1.0                 1.0
# 1                   2.0          3.0                2.0                 2.0
# 2                   0.0          2.0                1.0                 3.0
# 3                   0.0          2.0                2.0                 2.0
# 4                   0.0          1.0                2.0                 2.0
# ...                 ...          ...                ...                 ...
# 231045              2.0          2.0                2.0                 2.0
# 231046              0.0          0.0                0.0                 0.0
# 231047              3.0          3.0                2.0                 2.0
# 231048              3.0          3.0                2.0                 3.0
# 231049              0.0          2.0                1.0                 2.0
#
#         Mastery  Clones  CustomBlocks  InstancesSprites
# 0           3.0     0.0           0.0                 0
# 1          16.0     0.0           0.0                 1
# 2          10.0     0.0           2.0                 0
# 3           8.0     1.0           0.0                 0
# 4           6.0     0.0           0.0                 0
# ...         ...     ...           ...               ...
# 231045     13.0     1.0           0.0                 0
# 231046      0.0     0.0           0.0                 0
# 231047     17.0     0.0           0.0                 1
# 231048     20.0     4.0           3.0                 1
# 231049      7.0     0.0           0.0                 0
#
# [231050 rows x 20 columns]

# %%
data_path = "Data/scratch_projects.csv"
df.to_csv(data_path, index=False)
